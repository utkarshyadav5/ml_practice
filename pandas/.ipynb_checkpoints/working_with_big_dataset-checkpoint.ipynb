# %%
import pandas as pd

job = pd.read_csv('datasets/DOB_Job_Application_Filings.csv',sep=',')

job.head()
# Out:
#        Job #  Doc #        Borough       House #  \
# 0  121577873      2      MANHATTAN  386
# 1  520129502      1  STATEN ISLAND  107
# 2  121601560      1      MANHATTAN  63
# 3  121601203      1      MANHATTAN  48
# 4  121601338      1      MANHATTAN  45
#
#                         Street Name  Block   Lot      Bin # Job Type  \
# 0  PARK AVENUE SOUTH                   857  38.0  1016890.0       A2
# 1  KNOX PLACE                          342   1.0  5161350.0       A3
# 2  WEST 131 STREET                    1729   9.0  1053831.0       A2
# 3  WEST 25TH STREET                    826  69.0  1015610.0       A2
# 4  WEST 29 STREET                      831   7.0  1015754.0       A3
#
#   Job Status           ...                         Owner's Last Name  \
# 0          D           ...            MIGLIORE
# 1          A           ...            BLUMENBERG
# 2          Q           ...            MARKOWITZ
# 3          D           ...            CASALE
# ...

# %%
job.tail()
# Out:
#             Job #  Doc #    Borough House #          Street Name  Block   Lot  \
# 300558  140667605      1  MANHATTAN     325  WEST HOUSTON STREET    596  92.0
# 300559  421524256      1     QUEENS   38-24          32ND STREET    382  24.0
# 300560  340522606      1   BROOKLYN     318         TOMPKINS AVE   1814  31.0
# 300561  240190226      1      BRONX     355    EAST 204TH STREET   3349  47.0
# 300562  140667847      1  MANHATTAN     100     LEXINGTON AVENUE    883  20.0
#
#             Bin # Job Type Job Status           ...            \
# 300558  1010357.0       A2          D           ...
# 300559  4004601.0       A1          D           ...
# 300560  3051170.0       A2          H           ...
# 300561  2018430.0       A2          D           ...
# 300562  1018167.0       A2          H           ...
#
#        Owner's Last Name             Owner's Business Name  \
# 300558          VAN HOOK            UNITED PARCEL SERVICES
# ...

# %%
job.shape
# Out:
# (300563, 82)

# %%
job.columns
# Out:
# Index([u'Job #', u'Doc #', u'Borough', u'House #', u'Street Name', u'Block',
#        u'Lot', u'Bin #', u'Job Type', u'Job Status', u'Job Status Descrp',
#        u'Latest Action Date', u'Building Type', u'Community - Board',
#        u'Cluster', u'Landmarked', u'Adult Estab', u'Loft Board', u'City Owned',
#        u'Little e', u'PC Filed', u'eFiling Filed', u'Plumbing', u'Mechanical',
#        u'Boiler', u'Fuel Burning', u'Fuel Storage', u'Standpipe', u'Sprinkler',
#        u'Fire Alarm', u'Equipment', u'Fire Suppression', u'Curb Cut', u'Other',
#        u'Other Description', u'Applicant's First Name',
#        u'Applicant's Last Name', u'Applicant Professional Title',
#        u'Applicant License #', u'Professional Cert', u'Pre- Filing Date',
#        u'Paid', u'Fully Paid', u'Assigned', u'Approved', u'Fully Permitted',
#        u'Initial Cost', u'Total Est. Fee', u'Fee Status',
#        u'Existing Zoning Sqft', u'Proposed Zoning Sqft', u'Horizontal Enlrgmt',
# ...

# %%
# job.info() will tell us how many entries are empty 
# for example pc filed has 0 entries we can drop this

job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300563 entries, 0 to 300562
# Data columns (total 82 columns):
# Job #                           300563 non-null int64
# Doc #                           300563 non-null int64
# Borough                         300563 non-null object
# House #                         300563 non-null object
# Street Name                     300563 non-null object
# Block                           300563 non-null int64
# Lot                             300562 non-null float64
# Bin #                           300562 non-null float64
# Job Type                        300562 non-null object
# Job Status                      300562 non-null object
# Job Status Descrp               300562 non-null object
# Latest Action Date              300562 non-null object
# Building Type                   300562 non-null object
# Community - Board               300380 non-null object
# Cluster                         1 non-null object
# ...

# %%
# will give you the count mean min max e.t.c information

job.describe()
# Out:
#               Job #          Doc #          Block            Lot  \
# count  3.005630e+05  300563.000000  300563.000000  300562.000000
# mean   2.543056e+08       1.174020    2831.518740     614.671818
# std    1.327857e+08       0.555939    3201.971388    1986.236178
# min    1.036438e+08       1.000000       0.000000       0.000000
# 25%    1.225282e+08       1.000000     849.000000      12.000000
# 50%    2.205414e+08       1.000000    1499.000000      32.000000
# 75%    3.403377e+08       1.000000    3615.000000      59.000000
# max    5.401314e+08      13.000000   99999.000000    9999.000000
#
#               Bin #  PC Filed  Existing Zoning Sqft  Proposed Zoning Sqft  \
# count  3.005620e+05       0.0          3.005610e+05          3.005610e+05
# mean   2.404244e+06       NaN          1.929260e+03          2.535894e+03
# std    1.397203e+06       NaN          6.543388e+04          7.489102e+04
# min    1.000003e+06       NaN          0.000000e+00          0.000000e+00
# ...

# %%
# .describe can only be used on numerical columns
# for non-numerical we can use .value_counts
# this counted the frequency of Borough

job['Borough'].value_counts(dropna=False)
# Out:
# MANHATTAN        136936
# BROOKLYN          74694
# QUEENS            52137
# BRONX             22321
# STATEN ISLAND     14475
# Name: Borough, dtype: int64

# %% [markdown]
# ### Visualising to detect outliers

# %%
import matplotlib.pyplot as plt

job['Existing Zoning Sqft'].plot.hist(rot=70, logx=True, logy=True)
plt.show()

# the right most one can be an outlier

# %% [markdown]
# ##### To visualize multiple variables, boxplots are useful, especially when one of the variables is categorical.

# %%
job['Initial Cost']

# we can see that initial cost is a string thus we cant plot string with string one data has to be numeric
# Out:
# 0           $75000.00
# 1               $0.00
# 2           $30000.00
# 3            $1500.00
# 4           $19500.00
# 5         $3062400.00
# 6           $10000.00
# 7          $146800.00
# 8               $0.00
# 9            $5000.00
# 10          $21200.00
# 11          $20000.00
# 12          $37600.00
# 13          $10000.00
# 14           $3000.00
# 15              $0.00
# 16          $94000.00
# 17           $5000.00
# 18           $7500.00
# 19          $20000.00
# 20           $1000.00
# 21              $0.00
# 22          $67000.00
# 23          $70000.00
# 24              $0.00
# 25          $11000.00
# 26          $16000.00
# 27          $41000.00
# 28         $509500.00
# 29          $12238.00
#              ...
# 300533      $57120.00
# 300534          $0.00
# 300535      $40928.00
# 300536     $513200.00
# 300537          $0.00
# 300538      $15000.00
# 300539     $150000.00
# 300540      $23000.00
# 300541       $1000.00
# 300542          $0.00
# ...

# %%
# first we remove $ than convert it into float
job['Initial Cost']=job['Initial Cost'].str.replace('$','')
job['Initial Cost']=pd.to_numeric(job['Initial Cost'])
job['Initial Cost']
# Out:
# 0           75000.0
# 1               0.0
# 2           30000.0
# 3            1500.0
# 4           19500.0
# 5         3062400.0
# 6           10000.0
# 7          146800.0
# 8               0.0
# 9            5000.0
# 10          21200.0
# 11          20000.0
# 12          37600.0
# 13          10000.0
# 14           3000.0
# 15              0.0
# 16          94000.0
# 17           5000.0
# 18           7500.0
# 19          20000.0
# 20           1000.0
# 21              0.0
# 22          67000.0
# 23          70000.0
# 24              0.0
# 25          11000.0
# 26          16000.0
# 27          41000.0
# 28         509500.0
# 29          12238.0
#             ...
# 300533      57120.0
# 300534          0.0
# 300535      40928.0
# 300536     513200.0
# 300537          0.0
# 300538      15000.0
# 300539     150000.0
# 300540      23000.0
# 300541       1000.0
# 300542          0.0
# 300543    1175643.0
# 300544      15000.0
# 300545          0.0
# 300546      39396.0
# ...

# %%
# boxplot where y is a numeric value and x is non numeric

job.boxplot(column='Initial Cost',by='Borough',rot=90)
plt.show()

# %%
job['Total Est. Fee']=job['Total Est. Fee'].str.replace('$','')
job['Total Est. Fee']=pd.to_numeric(job['Total Est. Fee'])
job['Total Est. Fee']
# Out:
# 0           986.00
# 1          1144.00
# 2           522.50
# 3           225.00
# 4           389.50
# 5         31762.40
# 6           316.50
# 7          1727.60
# 8           160.00
# 9           265.00
# 10          440.10
# 11          419.50
# 12          764.90
# 13          316.50
# 14          280.00
# 15          472.00
# 16         1181.70
# 17          265.00
# 18          295.90
# 19          207.25
# 20          225.00
# 21          160.00
# 22         1063.60
# 23          934.50
# 24          440.00
# 25          326.80
# 26          378.30
# 27          635.80
# 28         5466.50
# 29          347.40
#             ...
# 300533      810.90
# 300534      170.00
# 300535      635.80
# 300536     5507.70
# 300537      160.00
# 300538      156.00
# 300539     1758.50
# 300540      450.40
# 300541      225.00
# 300542      180.00
# 300543    12326.30
# 300544      156.00
# 300545      250.00
# 300546      221.00
# 300547      250.00
# 300548     1243.50
# ...

# %%
# When you want to visualize two numeric columns, scatter plots are ideal.

job.plot(kind='scatter', x='Initial Cost',y='Total Est. Fee',rot=70)
plt.show()
